# %% [markdown]
# # Analysis of Baltimore's Social Venues for Prospective Businesses

# %% [markdown]
# ### Introduction

# %% [markdown]
# #### 1.1 Background

# %% [markdown]
# Land is a limited resource especially in urban areas. As Sagamore Developments is helping development new business ventures [1][2] and apartment/condo complexes being built throughout the city [3], Baltimore's population is heading towards a growth phase. Baltimore has set a standard for other cities for urban renewal with the redevelopment of the Inner Harbor in the late 1970's and the current development of one of the largest urban revitalization efforts in the United States with Port Covington [4] [5]. Outside of the Inner Harbor and Port Covington, there are numerous landmarks that promote tourism including, but not limited to Fort McHenry, Oriole Park at Camden Yards, the nationally ranked Aquarium, and several museums. Baltimore's expanding living complexes has also added to the growth potential as older town homes are getting torn down for the development of condo's that can house 100+ more people in the same amount of land.
#
# With the new developments, housing complexes, and tourism attractions, are there areas in the city where certain businesses will thrive and other areas where they will go bankrupt?

# %% [markdown]
# #### 1.2 Problem/Idea

# %% [markdown]
# The developments in Baltimore has the potential for a boom in population. Are there certain venues that excel where the new developments are being built? Are certain venues popular in neighborhoods by geological locations? Is the city divided into venue preference as the income can vary dramatically from South Baltimore to West Baltimore?

# %% [markdown]
# #### 1.3 Interest

# %% [markdown]
# Anyone who is interested in opening up a business in Baltimore. In the end, the reader should be able to understand the relationship between neighborhoods and venue preferences as well as where similar businesses are successfully operating.

# %% [markdown]
# ### 2. Data Acquisition

# %% [markdown]
# #### 2.1 Data Source

# %% [markdown]
# The data used to evaluate this problem:
#   * A list of Baltimore City neighborhoods by cardinal direction (North, South, East, West) [6] This data will provide all neighborhoods in Baltimore that will aid in finding latitudes and longitudes to be used with the Foursquare API.

# %% [markdown]
# |   | Neighborhood | Location     |
# |---|:------------:|-------------:|
# | 0 | Arlington    | Northwest    |
# | 1 | Arlington    | Northwest    |
# | 2 | Burleigh-Leighton| Northwest|
# | 3 | Callaway-Garrison| Northwest|
# | 4 |Central Forest Park| Northwest|

# %% [markdown]
#   * A CSV file of US zip codes was used to connect the neighborhoods with their corresponding zip code, latitude, and longitude. [7] The final file will be filtered on MD.

# %% [markdown]
# | | Zip | City | State| Latitude | Longitude |
# |-|:---:|:----:|:----:|:--------:|----------:|
# |0|71937| Cove | AR | 34.398483| -94.39398|
# |1|72044| Edgemont| AR| 35.624351| -92.16056|
# |2|56171| Sherurn| MN| 43.660847| -92.74357|
# |3|49430|Lamont| MI| 43.010337| -85.89754|
# |4|52585|Richland|IA|41.194129|-91.98027|

# %% [markdown]
#   * Foursquare API to get the trending and most popular venues. [8] This will help order the neighborhoods by venues.

# %% [markdown]
# ### 3. Methodology

# %% [markdown]
# #### 3. 1 Exploratory Data Analysis
# To explore the Baltimore landscape, I needed to first divide the city into sections. Luckily, wikipedia had a list of neighborhoods within their geological location and cardinal direction. After cleaning the data, I was able to map out the location of each neighborhood by their latitude and longitude coordinates. I wanted to first explore the types of venues each section of the city had and which were more popular in what areas. Below are the results. Each section of Baltimore was unique and with little overlap between the top 5 venues.

# %% [raw]
# ----Central----
#                  venue  freq
# 0       Sandwich Place  0.06
# 1                Hotel  0.04
# 2    Convenience Store  0.03
# 3          Coffee Shop  0.03
# 4  American Restaurant  0.03
# 5              Theater  0.03
# 6               Lounge  0.02
# 7          Pizza Place  0.02
# 8                 Café  0.02
# 9    Indian Restaurant  0.02
#
#
# ----East----
#                   venue  freq
# 0   American Restaurant  0.05
# 1           Coffee Shop  0.04
# 2        Sandwich Place  0.04
# 3    Chinese Restaurant  0.04
# 4     Convenience Store  0.04
# 5        Breakfast Spot  0.03
# 6  Fast Food Restaurant  0.03
# 7              Bus Stop  0.03
# 8                   Bar  0.03
# 9               Theater  0.03
#
#
# ----North----
#                  venue  freq
# 0          Pizza Place  0.04
# 1                  Bar  0.04
# 2          Coffee Shop  0.04
# 3             Pharmacy  0.03
# 4  American Restaurant  0.03
# 5       Sandwich Place  0.03
# 6    Korean Restaurant  0.02
# 7    Convenience Store  0.02
# 8         Liquor Store  0.02
# 9             Bus Stop  0.02
#
#
# ----Northeast----
#                  venue  freq
# 0   Italian Restaurant  0.06
# 1  American Restaurant  0.04
# 2    Convenience Store  0.04
# 3       Discount Store  0.03
# 4   Seafood Restaurant  0.03
# 5   Chinese Restaurant  0.03
# 6  Fried Chicken Joint  0.03
# 7          Pizza Place  0.03
# 8             Bus Stop  0.03
# 9                Hotel  0.02
#
#
# ----Northwest----
#                  venue  freq
# 0                 Park  0.06
# 1        Deli / Bodega  0.05
# 2   Chinese Restaurant  0.05
# 3  American Restaurant  0.05
# 4         Liquor Store  0.05
# 5       Discount Store  0.04
# 6             Pharmacy  0.04
# 7        Grocery Store  0.04
# 8  Arts & Crafts Store  0.04
# 9               Market  0.03
#
#
# ----South----
#                 venue  freq
# 0                 Bar  0.12
# 1         Pizza Place  0.06
# 2      Sandwich Place  0.04
# 3                Café  0.03
# 4  Seafood Restaurant  0.03
# 5    Sushi Restaurant  0.03
# 6  Mexican Restaurant  0.03
# 7        Liquor Store  0.03
# 8                 Pub  0.02
# 9   Convenience Store  0.02
#
#
# ----Southeast----
#                  venue  freq
# 0   Italian Restaurant  0.05
# 1                  Bar  0.05
# 2   Mexican Restaurant  0.04
# 3                Hotel  0.03
# 4  American Restaurant  0.03
# 5   Seafood Restaurant  0.03
# 6          Pizza Place  0.03
# 7          Coffee Shop  0.02
# 8       Clothing Store  0.02
# 9     Greek Restaurant  0.02
#
#
# ----Southwest----
#                              venue  freq
# 0                   Sandwich Place  0.05
# 1                Convenience Store  0.04
# 2                   History Museum  0.04
# 3              American Restaurant  0.04
# 4  Southern / Soul Food Restaurant  0.03
# 5                       Restaurant  0.03
# 6                      Coffee Shop  0.03
# 7                   Discount Store  0.03
# 8                      Pizza Place  0.03
# 9                        Nightclub  0.02
#
#
# ----West----
#                  venue  freq
# 0  American Restaurant  0.06
# 1       Sandwich Place  0.04
# 2  Fried Chicken Joint  0.04
# 3    Convenience Store  0.04
# 4   Chinese Restaurant  0.03
# 5          Pizza Place  0.03
# 6        Grocery Store  0.03
# 7                 Bank  0.03
# 8              Theater  0.02
# 9             Pharmacy  0.02

# %% [markdown]
# To enable the data to be more uniform, I took the mean of the frequency of occurrence of each venue by location. This made it possible to use k-means clustering to divide the venues into 5 clusters and show them on a visual map of Baltimore. By creating clusters, I was able to divide Baltimore into 5 sections by popular type of venue. This could help potential business owners in making decisions on where to buy land or buildings and start their business. The frequency of a venue in certain parts of the city can reflect the surrounding neighborhoods hobbies/spending habits. If the top venues are restaurants/bars as with South Baltimore, you can make the assumption it is more residential as opposed to Central Baltimore where their top venues are quick bites to eat/drink and hotels. Central Baltimore could be more of a business environment.

# %%
# Map of Baltimore in respective clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 3.2 Relationship Between Venue Preference and Neighborhood Location
# The neighborhoods were a great parameter for the types of venues in each location. There were some stray areas in sections throughout Baltimore where the clusters overlapped, but the majority of each cluster was divided similarly to their corresponding geological location. The hypothesis here is that each neighborhood, whereas they may be the same city, has different needs and priorities when it comes to leisurely time.

# %% [markdown]
# ### 4. Results

# %% [markdown]
# As you can see from the map above, the geological location of the city plays an important role in the popular venues as each cluster is separated similarly to the layout of the city by cardinal direction. I was able to identify the results of the popular venues and sort them into similar clusters. I built a model to help new or old business owners help predict where their type of business would succeed in Baltimore City. This data shows there is a definitive line within Baltimore City, with some restaurants/venues overlapping as popular throughout the city such as American restaurants and coffee shops. This data does not necessarily show where there is a gap or need in a particular corner of the city, it only reflects what is currently there.

# %% [markdown]
# ### 5. Discussion

# %% [markdown]
# As you can see from the table below, the neighborhoods are relatively even by locations with Northern parts being separated into more neighborhoods. There are some differences in the type of venue each section of Baltimore has. Central Baltimore looks like it is a possible a business district with high customer turnover venues such as coffee shops and convenience stores topping the list. South Baltimore has bars as the top location and then quick bites to eat. Looking at the top venues, this looks like a younger crowd that lives here, so if the owner is to open up a venue that targets the younger working generation, South Baltimore would be the best spot. Northwest Baltimore's top venues are parks and liquor stores. The two venues could be dependent of each other, but more research would have to be done on the demographic and possible income of the location. Food trucks could flourish a lot of places in Baltimore such as the Northwest, South, and Central as the Northwest has parks/liquor stores as the top location, easy access to food could be necessary. South Baltimore has bars and quick bites to eat and Central looks like a business district, so lunch time rushes and high customer turnover are great for food trucks.
#
# There is additional research on the neighborhoods themselves in my notebook that dives into the top venues in each of the 221 neighborhoods and clusters them into 5 groups. For additional data, please refer to the notebook to see results.

# %%
# View Neighborhood's total by cardinal direction
# Out:
# Northeast    31
# Southeast    23
# West         18
# Southwest    26
# Central      18
# Northwest    27
# North        44
# East         16
# South        18
# dtype: int64

# %% [markdown]
# #### South Baltimore Results

# %%
baltimore_merged.loc[baltimore_merged['Cluster Labels'] == 2, baltimore_merged.columns[[0] + list(range(4, baltimore_merged.shape[1]))]]
# Out:
#           Neighborhood  Cluster Labels 1st Most Common Venue  \
# 5         Arundel Cove               2                   Bar
# 20            Brooklyn               2                   Bar
# 21      Brooklyn Homes               2                   Bar
# 35         Cherry Hill               2                   Bar
# 41          Curtis Bay               2                   Bar
# 60        Federal Hill               2                   Bar
# 84          Harborview               2                   Bar
# 87       Hawkins Point               2                   Bar
# 109           Lakeland               2                   Bar
# 117       Locust Point               2                   Bar
# 122         Masonville               2                   Bar
# 136       Mount Winans               2                   Bar
# 162     Port Covington               2                   Bar
# 171          Riverside               2                   Bar
# 180   Sharp-Leadenhall               2                   Bar
# 195     Wagner's Point               2                   Bar
# 201  West Federal Hill               2                   Bar
# 208           Westport               2                   Bar
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5             Pizza Place        Sandwich Place                  Café
# 20            Pizza Place        Sandwich Place                  Café
# 21            Pizza Place        Sandwich Place                  Café
# 35            Pizza Place        Sandwich Place                  Café
# 41            Pizza Place        Sandwich Place                  Café
# 60            Pizza Place        Sandwich Place                  Café
# 84            Pizza Place        Sandwich Place                  Café
# 87            Pizza Place        Sandwich Place                  Café
# 109           Pizza Place        Sandwich Place                  Café
# 117           Pizza Place        Sandwich Place                  Café
# 122           Pizza Place        Sandwich Place                  Café
# 136           Pizza Place        Sandwich Place                  Café
# 162           Pizza Place        Sandwich Place                  Café
# 171           Pizza Place        Sandwich Place                  Café
# 180           Pizza Place        Sandwich Place                  Café
# 195           Pizza Place        Sandwich Place                  Café
# 201           Pizza Place        Sandwich Place                  Café
# 208           Pizza Place        Sandwich Place                  Café
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5        Sushi Restaurant                  Park    Mexican Restaurant
# 20       Sushi Restaurant                  Park    Mexican Restaurant
# 21       Sushi Restaurant                  Park    Mexican Restaurant
# 35       Sushi Restaurant                  Park    Mexican Restaurant
# 41       Sushi Restaurant                  Park    Mexican Restaurant
# 60       Sushi Restaurant                  Park    Mexican Restaurant
# 84       Sushi Restaurant                  Park    Mexican Restaurant
# 87       Sushi Restaurant                  Park    Mexican Restaurant
# 109      Sushi Restaurant                  Park    Mexican Restaurant
# 117      Sushi Restaurant                  Park    Mexican Restaurant
# 122      Sushi Restaurant                  Park    Mexican Restaurant
# 136      Sushi Restaurant                  Park    Mexican Restaurant
# 162      Sushi Restaurant                  Park    Mexican Restaurant
# 171      Sushi Restaurant                  Park    Mexican Restaurant
# 180      Sushi Restaurant                  Park    Mexican Restaurant
# 195      Sushi Restaurant                  Park    Mexican Restaurant
# 201      Sushi Restaurant                  Park    Mexican Restaurant
# 208      Sushi Restaurant                  Park    Mexican Restaurant
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 5      Seafood Restaurant                   Gym           Liquor Store
# 20     Seafood Restaurant                   Gym           Liquor Store
# 21     Seafood Restaurant                   Gym           Liquor Store
# 35     Seafood Restaurant                   Gym           Liquor Store
# 41     Seafood Restaurant                   Gym           Liquor Store
# 60     Seafood Restaurant                   Gym           Liquor Store
# 84     Seafood Restaurant                   Gym           Liquor Store
# 87     Seafood Restaurant                   Gym           Liquor Store
# 109    Seafood Restaurant                   Gym           Liquor Store
# 117    Seafood Restaurant                   Gym           Liquor Store
# 122    Seafood Restaurant                   Gym           Liquor Store
# 136    Seafood Restaurant                   Gym           Liquor Store
# 162    Seafood Restaurant                   Gym           Liquor Store
# 171    Seafood Restaurant                   Gym           Liquor Store
# 180    Seafood Restaurant                   Gym           Liquor Store
# 195    Seafood Restaurant                   Gym           Liquor Store
# 201    Seafood Restaurant                   Gym           Liquor Store
# 208    Seafood Restaurant                   Gym           Liquor Store

# %% [markdown]
# #### Northeast Baltimore Results

# %%
baltimore_merged.loc[baltimore_merged['Cluster Labels'] == 1, baltimore_merged.columns[[0] + list(range(4, baltimore_merged.shape[1]))]]
# Out:
#              Neighborhood  Cluster Labels 1st Most Common Venue  \
# 3               Arlington               1                  Park
# 6               Ashburton               1                  Park
# 23      Callaway-Garrison               1                  Park
# 31   Central Park Heights               1                  Park
# 36              Cheswolde               1                  Park
# 40          Cross Country               1                  Park
# 45               Dolfield               1                  Park
# 46             Dorchester               1                  Park
# 49         East Arlington               1                  Park
# 59              Fallstaff               1                  Park
# 63            Forest Park               1                  Park
# 69                   Glen               1                  Park
# 77             Grove Park               1                  Park
# 79              Gwynn Oak               1                  Park
# 81            Hanlon Park               1                  Park
# 96            Howard Park               1                  Park
# 110       Langston Hughes               1                  Park
# 115        Liberty Square               1                  Park
# 119          Lucille Park               1                  Park
# 150           Park Circle               1                  Park
# 151          Park Heights               1                  Park
# 160               Pimlico               1                  Park
# 165               Purnell               1                  Park
# 202      West Forest Park               1                  Park
# 203      West Hill Square               1                  Park
# 210         Windsor Hills               1                  Park
# 215              Woodmoor               1                  Park
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 3            Liquor Store   American Restaurant    Chinese Restaurant
# 6            Liquor Store   American Restaurant    Chinese Restaurant
# 23           Liquor Store   American Restaurant    Chinese Restaurant
# 31           Liquor Store   American Restaurant    Chinese Restaurant
# 36           Liquor Store   American Restaurant    Chinese Restaurant
# 40           Liquor Store   American Restaurant    Chinese Restaurant
# 45           Liquor Store   American Restaurant    Chinese Restaurant
# 46           Liquor Store   American Restaurant    Chinese Restaurant
# 49           Liquor Store   American Restaurant    Chinese Restaurant
# 59           Liquor Store   American Restaurant    Chinese Restaurant
# 63           Liquor Store   American Restaurant    Chinese Restaurant
# 69           Liquor Store   American Restaurant    Chinese Restaurant
# 77           Liquor Store   American Restaurant    Chinese Restaurant
# 79           Liquor Store   American Restaurant    Chinese Restaurant
# 81           Liquor Store   American Restaurant    Chinese Restaurant
# 96           Liquor Store   American Restaurant    Chinese Restaurant
# 110          Liquor Store   American Restaurant    Chinese Restaurant
# 115          Liquor Store   American Restaurant    Chinese Restaurant
# 119          Liquor Store   American Restaurant    Chinese Restaurant
# 150          Liquor Store   American Restaurant    Chinese Restaurant
# 151          Liquor Store   American Restaurant    Chinese Restaurant
# 160          Liquor Store   American Restaurant    Chinese Restaurant
# 165          Liquor Store   American Restaurant    Chinese Restaurant
# 202          Liquor Store   American Restaurant    Chinese Restaurant
# 203          Liquor Store   American Restaurant    Chinese Restaurant
# 210          Liquor Store   American Restaurant    Chinese Restaurant
# 215          Liquor Store   American Restaurant    Chinese Restaurant
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 3     Arts & Crafts Store         Grocery Store              Pharmacy
# 6     Arts & Crafts Store         Grocery Store              Pharmacy
# 23    Arts & Crafts Store         Grocery Store              Pharmacy
# 31    Arts & Crafts Store         Grocery Store              Pharmacy
# 36    Arts & Crafts Store         Grocery Store              Pharmacy
# 40    Arts & Crafts Store         Grocery Store              Pharmacy
# 45    Arts & Crafts Store         Grocery Store              Pharmacy
# 46    Arts & Crafts Store         Grocery Store              Pharmacy
# 49    Arts & Crafts Store         Grocery Store              Pharmacy
# 59    Arts & Crafts Store         Grocery Store              Pharmacy
# 63    Arts & Crafts Store         Grocery Store              Pharmacy
# 69    Arts & Crafts Store         Grocery Store              Pharmacy
# 77    Arts & Crafts Store         Grocery Store              Pharmacy
# 79    Arts & Crafts Store         Grocery Store              Pharmacy
# 81    Arts & Crafts Store         Grocery Store              Pharmacy
# 96    Arts & Crafts Store         Grocery Store              Pharmacy
# 110   Arts & Crafts Store         Grocery Store              Pharmacy
# 115   Arts & Crafts Store         Grocery Store              Pharmacy
# 119   Arts & Crafts Store         Grocery Store              Pharmacy
# 150   Arts & Crafts Store         Grocery Store              Pharmacy
# 151   Arts & Crafts Store         Grocery Store              Pharmacy
# 160   Arts & Crafts Store         Grocery Store              Pharmacy
# 165   Arts & Crafts Store         Grocery Store              Pharmacy
# 202   Arts & Crafts Store         Grocery Store              Pharmacy
# 203   Arts & Crafts Store         Grocery Store              Pharmacy
# 210   Arts & Crafts Store         Grocery Store              Pharmacy
# 215   Arts & Crafts Store         Grocery Store              Pharmacy
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3          Discount Store                Market      Convenience Store
# 6          Discount Store                Market      Convenience Store
# 23         Discount Store                Market      Convenience Store
# 31         Discount Store                Market      Convenience Store
# 36         Discount Store                Market      Convenience Store
# 40         Discount Store                Market      Convenience Store
# 45         Discount Store                Market      Convenience Store
# 46         Discount Store                Market      Convenience Store
# 49         Discount Store                Market      Convenience Store
# 59         Discount Store                Market      Convenience Store
# 63         Discount Store                Market      Convenience Store
# 69         Discount Store                Market      Convenience Store
# 77         Discount Store                Market      Convenience Store
# 79         Discount Store                Market      Convenience Store
# 81         Discount Store                Market      Convenience Store
# 96         Discount Store                Market      Convenience Store
# 110        Discount Store                Market      Convenience Store
# 115        Discount Store                Market      Convenience Store
# 119        Discount Store                Market      Convenience Store
# 150        Discount Store                Market      Convenience Store
# 151        Discount Store                Market      Convenience Store
# 160        Discount Store                Market      Convenience Store
# 165        Discount Store                Market      Convenience Store
# 202        Discount Store                Market      Convenience Store
# 203        Discount Store                Market      Convenience Store
# 210        Discount Store                Market      Convenience Store
# 215        Discount Store                Market      Convenience Store

# %% [markdown]
# #### Central Baltimore Results

# %%
baltimore_merged.loc[baltimore_merged['Cluster Labels'] == 0, baltimore_merged.columns[[0] + list(range(4, baltimore_merged.shape[1]))]]
# Out:
#            Neighborhood  Cluster Labels 1st Most Common Venue  \
# 0                 Abell               0           Coffee Shop
# 9          Barre Circle               0        Sandwich Place
# 11           Beechfield               0        Sandwich Place
# 17          Bolton Hill               0        Sandwich Place
# 24      Cameron Village               0           Coffee Shop
# ..                  ...             ...                   ...
# 213  Woodbourne Heights               0           Coffee Shop
# 214   Woodbourne-McCabe               0           Coffee Shop
# 217          Wyman Park               0           Coffee Shop
# 218           Wyndhurst               0           Coffee Shop
# 219        Yale Heights               0        Sandwich Place
#
#     2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0             Pizza Place                   Bar   American Restaurant
# 9     American Restaurant     Convenience Store        Discount Store
# 11    American Restaurant     Convenience Store        Discount Store
# 17                  Hotel           Coffee Shop     Convenience Store
# 24            Pizza Place                   Bar   American Restaurant
# ..                    ...                   ...                   ...
# 213           Pizza Place                   Bar   American Restaurant
# 214           Pizza Place                   Bar   American Restaurant
# 217           Pizza Place                   Bar   American Restaurant
# 218           Pizza Place                   Bar   American Restaurant
# 219   American Restaurant     Convenience Store        Discount Store
#
#     5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                Pharmacy        Sandwich Place                  Café
# 9          History Museum           Pizza Place   Fried Chicken Joint
# 11         History Museum           Pizza Place   Fried Chicken Joint
# 17                Theater   American Restaurant                  Café
# 24               Pharmacy        Sandwich Place                  Café
# ..                    ...                   ...                   ...
# 213              Pharmacy        Sandwich Place                  Café
# 214              Pharmacy        Sandwich Place                  Café
# 217              Pharmacy        Sandwich Place                  Café
# 218              Pharmacy        Sandwich Place                  Café
# 219        History Museum           Pizza Place   Fried Chicken Joint
#
#     8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0       Convenience Store    Chinese Restaurant           Liquor Store
# 9             Coffee Shop                 Hotel                    Pub
# 11            Coffee Shop                 Hotel                    Pub
# 17                    Bar           Pizza Place      Indian Restaurant
# 24      Convenience Store    Chinese Restaurant           Liquor Store
# ..                    ...                   ...                    ...
# 213     Convenience Store    Chinese Restaurant           Liquor Store
# 214     Convenience Store    Chinese Restaurant           Liquor Store
# 217     Convenience Store    Chinese Restaurant           Liquor Store
# 218     Convenience Store    Chinese Restaurant           Liquor Store
# 219           Coffee Shop                 Hotel                    Pub
#
# [88 rows x 12 columns]

# %% [markdown]
# ### 6. Conclusion/Further Research

# %% [markdown]
# The geological location of Baltimore can very much be separated into sections based on venue preferences. This data reflects the very divide in popular venues by division of Baltimore by cardinal direction. This research/data can be furthered by adding in demographic and possible income to there if the city is divided even further and help future store/restaurant owners decide on locations of their future openings. By adding additional data and knowing your own demographic, one could be open and run a successful business. One gap in this data is the fact it only takes into account what the popular venues are and not what the area is lacking. An area could be lacking a coffee shop, but there is no knowing if a coffee shop would be successful in that location.

# %% [markdown]
# ### References

# %% [markdown]
# [1] https://data.baltimoresun.com/news/port-covington/
#
# [2] https://www.portcovingtonrealestate.com/port-covington-development/
#
# [3] https://www.bizjournals.com/baltimore/news/2018/10/22/10-development-projects-changing-greater-baltimore.html#g/444001/1
#
# [4] https://www.tripadvisor.com/Tourism-g60811-Baltimore_Maryland-Vacations.html
#
# [5] https://www.portcovingtonrealestate.com/port-covington-development/
#
# [6] https://en.wikipedia.org/wiki/List_of_Baltimore_neighborhoods
#
# [7] https://public.opendatasoft.com/explore/dataset/us-zip-code-latitude-and-longitude/table/
#
# [8] https://developer.foursquare.com/
